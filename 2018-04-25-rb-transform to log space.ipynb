# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
p = np.random.rand(1,100)

# %%
p_log = np.log(p)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
scatter_plot = ax.scatter(np.arange(len(p_log[0])), p_log)
# Out:
# <img src="data:image/png;base64,..." width="640">
