# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
p = np.random.rand(1,100)

# %%
start = 0.0001
end = 1
a = np.log10(start)
b = np.log10(end)
distribution = np.random.rand(100)
r = np.sort(a * distribution)
x = np.power(10, r)

# %% [markdown]
# ### najpierw zrozum na papierze.

# %% [markdown]
# a teraz transfer to log space

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
exponential = ax.scatter(np.arange(100),x, s=.3)
linear = ax.scatter(np.arange(100), sorted(distribution), s=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
